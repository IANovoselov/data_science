# %%
import numpy as np
import pandas as pd

csv = pd.read_csv('StudentsPerformance.csv')
csv.head(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2458486586.py in <cell line: 0>()
#       2 import pandas as pd
#       3
# ----> 4 csv = pd.read_csv('StudentsPerformance.csv')
#       5 csv.head(10)
#
# ...

# %% [raw]
# csv.describe()

# %%
csv.dtypes.value_counts()

# %%
csv.groupby('gender').aggregate({'writing score' : 'mean'})

# %%
csv.iloc[0:5, 0:3]  # 0:5 - строки, 0:3 - колонки, или перечислять номерка строк/колонок через запятую

# %%
csv.head()

# %%
csv.loc[[0], ['gender']]

# %%
csv.iloc[[0,1,2], [0]]

# %%
csv['gender']

# %%
csv.iloc[:7]

# %%
csv.shape

# %%
csv2 = pd.read_csv('titanic.csv')

# %%
csv2.info()

# %%
csv.loc[csv.gender == 'female']

# %%
mean_value = csv['writing score'].mean()
csv.loc[csv['writing score'] > mean_value]

# %%
csv.loc[csv['lunch'] == 'free/reduced'].shape[0] / csv.shape[0]

# %%
csv.groupby('lunch').aggregate({'writing score': 'mean', 'math score': 'mean', 'reading score': 'mean', 'writing score': 'mean'})

# %%
csv.groupby('lunch').aggregate({'writing score' : 'var'})

# %%
csv['lunch']

# %%
csv.lunch

# %%
csv.query("gender == 'female'")

# %%
csv[['math score']]

# %%
csv[[i for i in list(csv) if 'score' in i]]

# %%
csv.filter(like='score')  # Колонки, содкжащие подстроку score axis=0 - в названии строк

# %%
csv.set_index('gender')

# %%
csv

# %%
csv.loc[[0]]

# %%
csv.iloc[[0]]

# %%
csv['pricol'] = 12

# %%
csv.head()

# %%
csv = pd.read_csv('dota_hero_stats.csv')
csv.groupby(['attack_type', 'primary_attr']).size()

# %%
csv.groupby('legs').size()

# %%
csv = pd.read_csv('accountancy.csv')
csv

# %%
csv.groupby(['Executor', 'Type']).aggregate({'Salary' : 'mean'})

# %%
csv = pd.read_csv('algae.csv')
csv

# %%
csv.groupby('group').size()

# %%
csv.groupby('group').aggregate({'glucose': ['max', 'min']})

# %%
import numpy as np
import pandas as pd
from sklearn import tree

dogs = pd.read_csv("https://stepik.org/media/attachments/course/4852/dogs.csv", index_col=0)
dogs
# Out:
#    Шерстист  Гавкает  Лазает по деревьям      Вид
# 0         1        1                   0  собачка
# 1         1        1                   0  собачка
# 2         1        1                   0  собачка
# 3         1        1                   0  собачка
# 4         1        0                   1    котик
# 5         1        0                   1    котик
# 6         1        0                   1    котик
# 7         1        0                   1    котик

# %%
dogs_X = dogs.iloc[:, :3]
dogs_y = dogs.iloc[:, 3]

dogs_clf = tree.DecisionTreeClassifier(criterion='entropy')
dogs_clf.fit(dogs_X, dogs_y)

tree.plot_tree(dogs_clf, feature_names=dogs_X.columns)
# Out:
# [Text(0.5, 0.75, 'Гавкает <= 0.5\nentropy = 1.0\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.25, 0.25, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.625, 0.5, '  False')]
