# %%
import numpy as np
import pandas as pd

csv = pd.read_csv('StudentsPerformance.csv')
csv.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# 5                    none          71             83             78
# 6               completed          88             95             92
# 7                    none          40             43             39
# 8               completed          64             64             67
# 9                    none          38             60             50

# %% [raw]
# csv.describe()

# %%
csv.dtypes.value_counts()
# Out:
# object    5
# int64     3
# Name: count, dtype: int64

# %%
csv.groupby('gender').aggregate({'writing score' : 'mean'})
# Out:
#         writing score
# gender
# female      72.467181
# male        63.311203

# %%
csv.iloc[0:5, 0:3]  # 0:5 - строки, 0:3 - колонки, или перечислять номерка строк/колонок через запятую
# Out:
#    gender race/ethnicity parental level of education
# 0  female        group B           bachelor's degree
# 1  female        group C                some college
# 2  female        group B             master's degree
# 3    male        group A          associate's degree
# 4    male        group C                some college

# %%
csv.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
csv.loc[[0], ['gender']]
# Out:
#    gender
# 0  female

# %%
csv.iloc[[0,1,2], [0]]
# Out:
#    gender
# 0  female
# 1  female
# 2  female

# %%
csv['gender']
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
csv.iloc[:7]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# 5                    none          71             83             78
# 6               completed          88             95             92

# %%
csv.shape
# Out:
# (1000, 8)

# %%
csv2 = pd.read_csv('titanic.csv')

# %%
csv2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 66.2+ KB

# %%
csv.loc[csv.gender == 'female']
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 5                      none          71             83             78
# 6                 completed          88             95             92
# ..                      ...         ...            ...            ...
# 993                    none          62             72             74
# 995               completed          88             99             95
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [518 rows x 8 columns]

# %%
mean_value = csv['writing score'].mean()
csv.loc[csv['writing score'] > mean_value]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 4                      none          76             78             75
# 5                      none          71             83             78
# ..                      ...         ...            ...            ...
# 992                    none          55             76             76
# 993                    none          62             72             74
# 995               completed          88             99             95
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [512 rows x 8 columns]

# %%
csv.loc[csv['lunch'] == 'free/reduced'].shape[0] / csv.shape[0]
# Out:
# 0.355

# %%
csv.groupby('lunch').aggregate({'writing score': 'mean', 'math score': 'mean', 'reading score': 'mean', 'writing score': 'mean'})
# Out:
#               writing score  math score  reading score
# lunch
# free/reduced      63.022535   58.921127      64.653521
# standard          70.823256   70.034109      71.654264

# %%
csv.groupby('lunch').aggregate({'writing score' : 'var'})
# Out:
#               writing score
# lunch
# free/reduced     238.202881
# standard         205.620887

# %%
csv['lunch']
# Out:
# 0          standard
# 1          standard
# 2          standard
# 3      free/reduced
# 4          standard
#            ...
# 995        standard
# 996    free/reduced
# 997    free/reduced
# 998        standard
# 999    free/reduced
# Name: lunch, Length: 1000, dtype: object

# %%
csv.lunch
# Out:
# 0          standard
# 1          standard
# 2          standard
# 3      free/reduced
# 4          standard
#            ...
# 995        standard
# 996    free/reduced
# 997    free/reduced
# 998        standard
# 999    free/reduced
# Name: lunch, Length: 1000, dtype: object

# %%
csv.query("gender == 'female'")
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 5                      none          71             83             78
# 6                 completed          88             95             92
# ..                      ...         ...            ...            ...
# 993                    none          62             72             74
# 995               completed          88             99             95
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [518 rows x 8 columns]

# %%
csv[['math score']]
# Out:
#      math score
# 0            72
# 1            69
# 2            90
# 3            47
# 4            76
# ..          ...
# 995          88
# 996          62
# 997          59
# 998          68
# 999          77
#
# [1000 rows x 1 columns]

# %%
csv[[i for i in list(csv) if 'score' in i]]
# Out:
#      math score  reading score  writing score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# ..          ...            ...            ...
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86
#
# [1000 rows x 3 columns]

# %%
csv.filter(like='score')  # Колонки, содкжащие подстроку score axis=0 - в названии строк
# Out:
#      math score  reading score  writing score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# ..          ...            ...            ...
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86
#
# [1000 rows x 3 columns]

# %%
csv.set_index('gender')
# Out:
#        race/ethnicity parental level of education         lunch  \
# gender
# female        group B           bachelor's degree      standard
# female        group C                some college      standard
# female        group B             master's degree      standard
# male          group A          associate's degree  free/reduced
# male          group C                some college      standard
# ...               ...                         ...           ...
# female        group E             master's degree      standard
# male          group C                 high school  free/reduced
# female        group C                 high school  free/reduced
# female        group D                some college      standard
# female        group D                some college  free/reduced
#
#        test preparation course  math score  reading score  writing score
# gender
# female                    none          72             72             74
# female               completed          69             90             88
# female                    none          90             95             93
# male                      none          47             57             44
# male                      none          76             78             75
# ...                        ...         ...            ...            ...
# female               completed          88             99             95
# male                      none          62             55             55
# female               completed          59             71             65
# female               completed          68             78             77
# female                    none          77             86             86
#
# [1000 rows x 7 columns]

# %%
csv
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %%
csv.loc[[0]]
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74

# %%
csv.iloc[[0]]
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74

# %%
csv['pricol'] = 12

# %%
csv.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  pricol
# 0                    none          72             72             74      12
# 1               completed          69             90             88      12
# 2                    none          90             95             93      12
# 3                    none          47             57             44      12
# 4                    none          76             78             75      12

# %%
csv = pd.read_csv('dota_hero_stats.csv')
csv.groupby(['attack_type', 'primary_attr']).size()
# Out:
# attack_type  primary_attr
# Melee        agi             19
#              int              2
#              str             35
# Ranged       agi             18
#              int             40
#              str              3
# dtype: int64

# %%
csv.groupby('legs').size()
# Out:
# legs
# 0    11
# 2    95
# 4     7
# 6     3
# 8     1
# dtype: int64

# %%
csv = pd.read_csv('accountancy.csv')
csv
# Out:
#     Unnamed: 0 Executor Type  Salary
# 0            0     Pupa    D      63
# 1            1     Pupa    A     158
# 2            2     Pupa    D     194
# 3            3     Pupa    E     109
# 4            4    Loopa    E     184
# 5            5    Loopa    F     232
# 6            6    Loopa    B     249
# 7            7     Pupa    F     195
# 8            8     Pupa    A     115
# 9            9     Pupa    E      65
# 10          10    Loopa    C     145
# 11          11    Loopa    D     149
# 12          12    Loopa    B      50
# 13          13     Pupa    A     217
# 14          14    Loopa    D     110
# 15          15     Pupa    F      62
# 16          16     Pupa    A      55
# 17          17    Loopa    B     190
# 18          18    Loopa    E      83
# 19          19     Pupa    A     234
# 20          20    Loopa    E     156
# 21          21    Loopa    E     219
# 22          22     Pupa    C      55
# 23          23     Pupa    D     144
# 24          24     Pupa    C      94
# 25          25    Loopa    C     175
# 26          26    Loopa    D      78
# 27          27    Loopa    C      81
# 28          28     Pupa    E     197
# 29          29     Pupa    E     193
# 30          30     Pupa    E      92
# 31          31     Pupa    D     185
# 32          32    Loopa    B     128
# 33          33     Pupa    F     146
# 34          34    Loopa    B      69
# 35          35    Loopa    F     244
# 36          36    Loopa    E     122
# 37          37    Loopa    C     222
# 38          38    Loopa    D     181
# 39          39     Pupa    A     186
# 40          40    Loopa    D     172
# 41          41     Pupa    B      77
# 42          42    Loopa    E     220
# 43          43    Loopa    B     185
# 44          44    Loopa    C     249
# 45          45    Loopa    D     146
# 46          46    Loopa    A      58
# 47          47    Loopa    C      54
# 48          48     Pupa    F     142
# 49          49    Loopa    D     128

# %%
csv.groupby(['Executor', 'Type']).aggregate({'Salary' : 'mean'})
# Out:
#                    Salary
# Executor Type
# Loopa    A      58.000000
#          B     145.166667
#          C     154.333333
#          D     137.714286
#          E     164.000000
#          F     238.000000
# Pupa     A     160.833333
#          B      77.000000
#          C      74.500000
#          D     146.500000
#          E     131.200000
#          F     136.250000

# %%
csv = pd.read_csv('algae.csv')
csv
# Out:
#                 species        genus  group   sucrose    alanin   citrate  \
# 0     Fucus_vesiculosus        Fucus  brown  3.001472  3.711498  5.004262
# 1   Saccharina_japonica   Saccharina  brown  6.731070  1.255251  5.621499
# 2        Fucus_serratus        Fucus  brown  3.276870  0.346431  1.216767
# 3       Fucus_distichus        Fucus  brown  6.786996  6.641303  6.423606
# 4     Cladophora_fracta   Cladophora  green  3.861470  1.648450  6.940588
# 5   Cladophora_compacta   Cladophora  green  5.712284  3.461692  3.082826
# 6   Cladophora_gracilis   Cladophora  green  2.452623  6.881024  5.841520
# 7      Palmaria_palmata     Palmaria    red  0.704580  3.176440  5.573905
# 8  Saccharina_latissima   Saccharina  brown  1.636122  5.793163  1.071920
# 9   Ascophyllum_nodosum  Ascophyllum  brown  6.825467  0.875429  5.253527
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886
# 5  3.343707    1.432514
# 6  2.740165    2.829016
# 7  3.242090    2.245538
# 8  3.947968    4.817804
# 9  3.414961    2.432526

# %%
csv.groupby('group').size()
# Out:
# group
# brown    6
# green    3
# red      1
# dtype: int64

# %%
csv.groupby('group').aggregate({'glucose': ['max', 'min']})
# Out:
#         glucose
#             max       min
# group
# brown  6.013219  2.272724
# green  3.343707  2.316955
# red    3.242090  3.242090

# %%
# Визуализация
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
csv = pd.read_csv('StudentsPerformance.csv')
csv
# Гистограмма по конкретному столбцу
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[64], line 2
#       1 # Визуализация
# ----> 2 get_ipython().run_line_magic('matplotlib', 'inline')
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
#
# File c:\saby\home\data_science\venv\Lib\site-packages\IPython\core\interactiveshell.py:2432, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2430     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2431 with self.builtin_trap:
# -> 2432     result = fn(*args, **kwargs)
#    2434 # The code below prevents the output from being displayed
#    2435 # when using magics with decorator @output_can_be_silenced
#    2436 # when the last Python token in the expression is a ';'.
#    2437 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File c:\saby\home\data_science\venv\Lib\site-packages\IPython\core\magics\pylab.py:99, in PylabMagics.matplotlib(self, line)
#      97     print("Available matplotlib backends: %s" % backends_list)
#      98 else:
# ---> 99     gui, backend = self.shell.enable_matplotlib(args.gui.lower() if isinstance(args.gui, str) else args.gui)
#     100     self._show_matplotlib_backend(args.gui, backend)
#
# File c:\saby\home\data_science\venv\Lib\site-packages\IPython\core\interactiveshell.py:3606, in InteractiveShell.enable_matplotlib(self, gui)
#    3585 def enable_matplotlib(self, gui=None):
#    3586     """Enable interactive matplotlib and inline figure support.
#    3587
#    3588     This takes the following steps:
#    (...)
#    3604         display figures inline.
#    3605     """
# -> 3606     from matplotlib_inline.backend_inline import configure_inline_support
#    3608     from IPython.core import pylabtools as pt
#    3609     gui, backend = pt.find_gui_and_backend(gui, self.pylab_gui_select)
#
# File c:\saby\home\data_science\venv\Lib\site-packages\matplotlib_inline\__init__.py:1
# ----> 1 from . import backend_inline, config  # noqa
#       2 __version__ = "0.1.6"  # noqa
#
# File c:\saby\home\data_science\venv\Lib\site-packages\matplotlib_inline\backend_inline.py:6
#       1 """A matplotlib backend for publishing figures via display_data"""
#       3 # Copyright (c) IPython Development Team.
#       4 # Distributed under the terms of the BSD 3-Clause License.
# ----> 6 import matplotlib
#       7 from matplotlib import colors
#       8 from matplotlib.backends import backend_agg
#
# ModuleNotFoundError: No module named 'matplotlib'
